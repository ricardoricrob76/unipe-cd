# %% [markdown]
# <a href="https://colab.research.google.com/github/ricardoricrob76/unipe-cd/blob/main/Aula1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Análise Exploratória dos Jogadores da NBA 1996 até 2021

# %%
# Importando as bibliotecas do Python
import numpy as np
import scipy as sp
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Lendo o arquivo CSV
df = pd.read_csv("all_seasons.csv")

# %%
# Exibindo as primeiras linhas da DF
df.head(10)
# Out:
#    Unnamed: 0        player_name team_abbreviation   age  player_height  \
# 0           0      Dennis Rodman               CHI  36.0         198.12
# 1           1  Dwayne Schintzius               LAC  28.0         215.90
# 2           2       Earl Cureton               TOR  39.0         205.74
# 3           3        Ed O'Bannon               DAL  24.0         203.20
# 4           4        Ed Pinckney               MIA  34.0         205.74
# 5           5      Eddie Johnson               HOU  38.0         200.66
# 6           6        Eddie Jones               LAL  25.0         198.12
# 7           7     Elden Campbell               LAL  28.0         213.36
# 8           8  Eldridge Recasner               ATL  29.0         193.04
# 9           9       Elliot Perry               MIL  28.0         182.88
#
#    player_weight                      college country draft_year draft_round  \
# 0      99.790240  Southeastern Oklahoma State     USA       1986           2
# ...

# %%
# Explorando DAdos e Usando Gráficos.

# %%
# Mostrando Gráficos com Python no Notebook
# %matplotlib inline

# %%
# Usando Matplotlib para desenhar um histogram para a coluna Idade
plt.hist(df['age'],bins=8)
# Out:
# (array([ 862., 3212., 3128., 2364., 1972.,  585.,  165.,   17.]),
#  array([18.  , 21.25, 24.5 , 27.75, 31.  , 34.25, 37.5 , 40.75, 44.  ]),
#  <a list of 8 Patch objects>)

# %%
dfCurry = df.loc[df["player_name"] == "Stephen Curry"]

# %%
dfCurry
# Out:
#        Unnamed: 0    player_name team_abbreviation   age  player_height  \
# 5926         5926  Stephen Curry               GSW  22.0         190.50
# 6361         6361  Stephen Curry               GSW  23.0         190.50
# 6999         6999  Stephen Curry               GSW  24.0         190.50
# 7173         7173  Stephen Curry               GSW  25.0         190.50
# 7838         7838  Stephen Curry               GSW  26.0         190.50
# 8292         8292  Stephen Curry               GSW  27.0         190.50
# 8739         8739  Stephen Curry               GSW  28.0         190.50
# 9182         9182  Stephen Curry               GSW  29.0         190.50
# 9877         9877  Stephen Curry               GSW  30.0         190.50
# 10141       10141  Stephen Curry               GSW  31.0         190.50
# 10869       10869  Stephen Curry               GSW  32.0         190.50
# 11335       11335  Stephen Curry               GSW  33.0         190.50
# ...

# %%
plt.figure(figsize=(20,7))
plt.title("Média de Pontos por Temporada")
plt.plot(dfCurry['season'], dfCurry['pts'])
plt.show()
