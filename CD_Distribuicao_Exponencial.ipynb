# %% [markdown]
# <a href="https://colab.research.google.com/github/ricardoricrob76/unipe-cd/blob/main/CD_Distribuicao_Exponencial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Estatística - Distribuição exponencial

# %% [markdown]
# * Calculando uma distribuição exponencial do zero
# * @ricardoricrob
# * Prof. MSc. Ricardo Roberto de Lima
# * ricardorobertolima@gmail.com

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import math

# %%
X = np.linspace(0,3,31)

# %%
lam = [0.5,1.0,1.5,2.0,2.5,3.0]

# %%
colors = ['black','red','blue','green','orange','cyan']

# %%
fs = []

for i in range(len(lam)):
    f = lam[i]*np.exp(-1.0*lam[i]*X)
    fs.append(f)

# %%
for i in range(len(lam)):
    plt.plot(X,fs[i],color=colors[i],label=r'$\lambda$='+str(lam[i]))

plt.xlabel('X')
plt.ylabel(r'f(X,$\lambda$)')
plt.legend()
plt.tight_layout()

# %% [markdown]
# Gerando números aleatórios

# %%
lam = 2.0
beta = 1.0/lam

# %%
e = np.random.exponential(scale=beta,size=1000)

# %%
bins=10
plt.hist(e, bins, density=True)
bin = np.linspace(0,4,401)
y = (1/beta)*np.exp(-1.0*bin/beta)
plt.plot(bin,y,color='red')
plt.tight_layout()
